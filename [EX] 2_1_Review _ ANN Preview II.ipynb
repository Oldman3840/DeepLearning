# %% [markdown]
# # 1일차 Review : 같은 문제 다시 풀어보기
# ---
# - 학습은 10번만!

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
x = cancer.data
y = cancer.target

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
pd.DataFrame(x, columns=cancer.feature_names).head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# ...

# %%
# pd.DataFrame(y, columns=cancer.target_names).head(3)

# pd.DataFrame(y, columns=cancer.target_names).head(3)

# %%
###########################
# train set / test set 분리
###########################

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 2023)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
#####################
# 라이브러리 불러오기
#####################
import tensorflow
from tensorflow import keras

# %%
########
# 모델링
########
# 1. 세션 클리어
keras.backend.clear_session()

# 2. 모델 선언
model = keras.models.Sequential()

# 3. 모델 블록 조립
model.add(keras.layers.Input(30, ))
model.add(keras.layers.Dense(1, activation = 'sigmoid'))

# 4. 컴파일
model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'], optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 31
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs= 10, verbose= 1)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 10.7143 - accuracy: 0.3714
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 2.8885 - accuracy: 0.4374
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 2.3899 - accuracy: 0.3582
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.9234 - accuracy: 0.4813
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6745 - accuracy: 0.4835
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4916 - accuracy: 0.5099
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2894 - accuracy: 0.5714
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1657 - accuracy: 0.6220
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.1308 - accuracy: 0.5912
# Epoch 10/10
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
###########
# 모델 예측
###########
result = pd.DataFrame()
result['y'] = y_test
result['y_pred'] = y_pred
result['y_pred_r'] = y_pred.round(0)
result['diff'] = np.where(result['y'] == result['y_pred_r'], True, False)
result
# Out:
#      y    y_pred  y_pred_r   diff
# 0    0  0.484902       0.0   True
# 1    0  0.984331       1.0  False
# 2    1  0.628461       1.0   True
# 3    0  0.000011       0.0   True
# 4    0  0.921074       1.0  False
# ..  ..       ...       ...    ...
# 109  1  0.662934       1.0   True
# 110  1  0.963915       1.0   True
# 111  1  0.929032       1.0   True
# 112  1  0.604214       1.0   True
# 113  0  0.892048       1.0  False
#
# [114 rows x 4 columns]

# %%
print(result['diff'].sum()/result.shape[0] * 100, '%')
# Out:
# 76.31578947368422 %

# %% [markdown]
# # 히든 레이어 추가하여 모델링!
# ---
# - 조건
#     - 히든 레이어 2개를 추가하여 다시 모델링!
#     - 히든 레이어 노드 수 : 32
#     - 히든 레이어 activation = 'relu'

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
########
# 모델링
########
# 1. 세션 클리어
keras.backend.clear_session()

# 2. 모델 선언
model = keras.models.Sequential()

# 3. 모델 블록 추가
model.add(keras.layers.Input(shape = (30, )))
model.add(keras.layers.Dense(32, activation = 'relu'))
model.add(keras.layers.Dense(32, activation = 'relu'))
model.add(keras.layers.Dense(1, activation = 'sigmoid'))

# 4. 컴파일
model.compile(loss = 'binary_crossentropy', metrics= ['accuracy'], optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs = 10, verbose = 1)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 1ms/step - loss: 14.4438 - accuracy: 0.4352
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 1.7122 - accuracy: 0.7121
# Epoch 3/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6632 - accuracy: 0.8088
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5307 - accuracy: 0.8396
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4726 - accuracy: 0.8527
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.8725
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8440
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.8747
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.8747
# Epoch 10/10
# ...

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
result['y_pred_2'] = y_pred
result['y_pred_2_r'] = y_pred.round(0)
result['diff_2'] = np.where(result['y'] == result['y_pred_2_r'], True, False)

# %%
print(result['diff_2'].sum()/result.shape[0] * 100, '%')
result
# Out:
# 89.47368421052632 %
#      y      y_pred_2  y_pred_2_r  diff_2
# 0    0  4.436172e-03         0.0    True
# 1    0  5.624945e-01         1.0   False
# 2    1  4.724640e-01         0.0   False
# 3    0  1.064785e-06         0.0    True
# 4    0  6.366506e-16         0.0    True
# ..  ..           ...         ...     ...
# 109  1  9.831267e-01         1.0    True
# 110  1  4.064042e-01         0.0   False
# 111  1  9.034613e-01         1.0    True
# 112  1  9.040347e-01         1.0    True
# 113  0  1.678283e-05         0.0    True
#
# [114 rows x 4 columns]
